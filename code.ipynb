# %%
import tweepy

# %%
import jsonpickle

# %%
import pandas as pd
import tweepy
import jsonpickle
import json
import re
import matplotlib as plt
import numpy as np

# %%
CONSUMER_KEY    = 'sz6x0nvL0ls9wacR64MZu23z4'
CONSUMER_SECRET = 'ofeGnzduikcHX6iaQMqBCIJ666m6nXAQACIAXMJaFhmC6rjRmT'
ACCESS_TOKEN  = '854004678127910913-PUPfQYxIjpBWjXOgE25kys8kmDJdY0G'
ACCESS_SECRET = 'BC2TxbhKXkdkZ91DXofF7GX8p2JNfbpHqhshW1bwQkgxN'
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    
    api = tweepy.API(auth)
    return api
api = connect_to_twitter_OAuth()

# %%
def get_save_tweets(filepath, api, query, max_tweets=50000, lang='en'):

    tweetCount = 0

    #Open file and save tweets
    with open(filepath, 'w') as f:

        # Send the query
        for tweet in tweepy.Cursor(api.search,q=query,lang=lang).items(max_tweets):         

            #Convert to JSON format
            f.write(jsonpickle.encode(tweet._json, unpicklable=False) + '\n')
            tweetCount += 1

        #Display how many tweets we have collected
        print("Downloaded {0} tweets".format(tweetCount))

# %%
query = '#realmadrid OR #barcelona OR #atletico OR #sevilla OR #valencia'

# Get those tweets
get_save_tweets('tweets.json', api, query)

# %%
def tweets_to_df(path):
    
    tweets = list(open('tweets.json', 'rt'))
    
    text = []
    weekday = []
    month = []
    day = []
    hour = []
    hashtag = []
    url = []
    favorite = []
    reply = []
    retweet = []
    follower = []
    following = []
    user = []
    location = []
    screen_name = []

    for t in tweets:
        t = jsonpickle.decode(t)
        
        # Text
        text.append(t['text'])
        
        # Decompose date
        date = t['created_at']
        weekday.append(date.split(' ')[0])
        month.append(date.split(' ')[1])
        day.append(date.split(' ')[2])
        
        time = date.split(' ')[3].split(':')
        hour.append(time[0]) 
        
        # Has hashtag
        if len(t['entities']['hashtags']) == 0:
            hashtag.append(0)
        else:
            hashtag.append(1)
            
        # Has url
        if len(t['entities']['urls']) == 0:
            url.append(0)
        else:
            url.append(1)
            
        # Number of favs
        favorite.append(t['favorite_count'])
        
        # Is reply?
        if t['in_reply_to_status_id'] == None:
            reply.append(0)
        else:
            reply.append(1)       
        
        # Retweets count
        retweet.append(t['retweet_count'])
        
        # Followers number
        follower.append(t['user']['followers_count'])
        
        # Following number
        following.append(t['user']['friends_count'])
        
        # Add user
        user.append(t['user']['name'])
        
        # Add location
        location.append(t['user']['location'])

        # Add screen name
        screen_name.append(t['user']['screen_name'])
        
    d = {'text': text,
         'weekday': weekday,
         'month' : month,
         'day': day,
         'hour' : hour,
         'has_hashtag': hashtag,
         'has_url': url,
         'fav_count': favorite,
         'is_reply': reply,
         'retweet_count': retweet,
         'followers': follower,
         'following' : following,
         'user': user,
         'location': location,
         'screen_name' : screen_name
        }
    
    return pd.DataFrame(data = d)
        
tweets_df = tweets_to_df('tweets.json')

# %%
def tweets_to_df(path):
    
    tweets = list(open('tweets1.json', 'rt'))
    
    text = []
    weekday = []
    month = []
    day = []
    hour = []
    hashtag = []
    url = []
    favorite = []
    reply = []
    retweet = []
    follower = []
    following = []
    user = []
    location = []
    screen_name = []

    for t in tweets:
        t = jsonpickle.decode(t)
        
        # Text
        text.append(t['text'])
        
        # Decompose date
        date = t['created_at']
        weekday.append(date.split(' ')[0])
        month.append(date.split(' ')[1])
        day.append(date.split(' ')[2])
        
        time = date.split(' ')[3].split(':')
        hour.append(time[0]) 
        
        # Has hashtag
        if len(t['entities']['hashtags']) == 0:
            hashtag.append(0)
        else:
            hashtag.append(1)
            
        # Has url
        if len(t['entities']['urls']) == 0:
            url.append(0)
        else:
            url.append(1)
            
        # Number of favs
        favorite.append(t['favorite_count'])
        
        # Is reply?
        if t['in_reply_to_status_id'] == None:
            reply.append(0)
        else:
            reply.append(1)       
        
        # Retweets count
        retweet.append(t['retweet_count'])
        
        # Followers number
        follower.append(t['user']['followers_count'])
        
        # Following number
        following.append(t['user']['friends_count'])
        
        # Add user
        user.append(t['user']['name'])
        
        # Add location
        location.append(t['user']['location'])

        # Add screen name
        screen_name.append(t['user']['screen_name'])
        
    d = {'text': text,
         'weekday': weekday,
         'month' : month,
         'day': day,
         'hour' : hour,
         'has_hashtag': hashtag,
         'has_url': url,
         'fav_count': favorite,
         'is_reply': reply,
         'retweet_count': retweet,
         'followers': follower,
         'following' : following,
         'user': user,
         'location': location,
         'screen_name' : screen_name
        }
    
    return pd.DataFrame(data = d)
        
tweets_df2 = tweets_to_df('tweets1.json')

# %%
def tweets_to_df(path):
    
    tweets = list(open('tweets2.json', 'rt'))
    
    text = []
    weekday = []
    month = []
    day = []
    hour = []
    hashtag = []
    url = []
    favorite = []
    reply = []
    retweet = []
    follower = []
    following = []
    user = []
    location = []
    screen_name = []

    for t in tweets:
        t = jsonpickle.decode(t)
        
        # Text
        text.append(t['text'])
        
        # Decompose date
        date = t['created_at']
        weekday.append(date.split(' ')[0])
        month.append(date.split(' ')[1])
        day.append(date.split(' ')[2])
        
        time = date.split(' ')[3].split(':')
        hour.append(time[0]) 
        
        # Has hashtag
        if len(t['entities']['hashtags']) == 0:
            hashtag.append(0)
        else:
            hashtag.append(1)
            
        # Has url
        if len(t['entities']['urls']) == 0:
            url.append(0)
        else:
            url.append(1)
            
        # Number of favs
        favorite.append(t['favorite_count'])
        
        # Is reply?
        if t['in_reply_to_status_id'] == None:
            reply.append(0)
        else:
            reply.append(1)       
        
        # Retweets count
        retweet.append(t['retweet_count'])
        
        # Followers number
        follower.append(t['user']['followers_count'])
        
        # Following number
        following.append(t['user']['friends_count'])
        
        # Add user
        user.append(t['user']['name'])
        
        # Add location
        location.append(t['user']['location'])

        # Add screen name
        screen_name.append(t['user']['screen_name'])
        
    d = {'text': text,
         'weekday': weekday,
         'month' : month,
         'day': day,
         'hour' : hour,
         'has_hashtag': hashtag,
         'has_url': url,
         'fav_count': favorite,
         'is_reply': reply,
         'retweet_count': retweet,
         'followers': follower,
         'following' : following,
         'user': user,
         'location': location,
         'screen_name' : screen_name
        }
    
    return pd.DataFrame(data = d)
        
tweets_df3 = tweets_to_df('tweets2.json')

# %%
len(tweets_df2)
len(tweets_df3)

# %%
tweets_df3.head(2)

# %%
tweets_df2.head()

# %%
df = pd.concat([tweets_df2, tweets_df3])

# %%
len(df)

# %%
df['lower case'] = df['text'].str.lower() #coverting tweets to lower case

# %%
df['E'] = df['lower case'].map(lambda x: re.sub(r'\W+', ' ', x)) #removing all the special characters, links, URLs, blank spaces

# %%
df['E']
# Out:
# 0       good morning barcelona good advice for barça f...
# 1       rt yusufchambers mosalah gets injured ramadhan...
# 2        finalscoresbet fsb winfornow this is the most...
# 3       rt lfcphoto no problem lfc livbar championslea...
# 4       rt marcabimbo we choose to believe in us mazai...
# 5       rt lfcphoto no problem lfc livbar championslea...
# 6       rt oluwafemig 60secondswithfemi korrect pidgin...
# 7        barcelona i am inevitable liverpool i am live...
# 8       which lfc comeback was better championsleague ...
# 9       real madrid prepare world record bid for kylia...
# 10      rt nialloloughlin unbelievable match maybe the...
# 11      who saw last night coming wooooah let s hear y...
# 12       dublin joins barcelona belgrade buenosaires d...
# 13      rt ivanvaldezpy not today liverpool barcelona ...
# 14      rt naira4dollar never give up on what you real...
# 15      rt waltermurimi92 messi to dembele in the lock...
# ...

# %%
df.head(2)

# %%
del df['lowercase3']

# %%
df.head(2)

# %%
df_rm = df[df['E'].str.contains("realmadrid") | df['E'].str.contains("real madrid") |df['E'].str.contains("rma")] #tweets containing real madrid
df_barca = df[df['E'].str.contains("barcelona") | df['E'].str.contains("barca") |df['E'].str.contains("fcb")] #tweets contaiining barcelona
df_atm = df[df['E'].str.contains("atletico") | df['E'].str.contains("atm")] #tweets contaiining atletico
df_sev = df[df['E'].str.contains("sevilla") | df['E'].str.contains("sev")] #tweets contaiining sevilla
df_val = df[df['E'].str.contains("valencia") | df['E'].str.contains("val")] #tweets contaiining valencia

# %%
len(df_rm) # occurrence of real madrid tweets
# Out:
# 132

# %%
len(df_barca) #occurrence of barcelona tweets
# Out:
# 3038

# %%
len(df_atm) #occurrence of atletico madrid tweets
# Out:
# 33

# %%
len(df_sev)  #occurrence of sevilla tweets
# Out:
# 29

# %%
len(df_val) #occurrence of valencia tweets
# Out:
# 216

# %%
from textblob import TextBlob

# %%
import re
import numpy as np

# %%
def clean_tweet(tweet):
    '''
    Utility function to clean the text in a Tweet by removing 
    links and special characters using regex re.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility TextBlob to classify the polarity of a Tweet
    using TextBlob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
df_rm['Score'] = np.array([ analize_sentiment(tweet) for tweet in df_rm['E'] ])
df_barca['Score'] = np.array([ analize_sentiment(tweet) for tweet in df_barca['E'] ])
df_atm['Score'] = np.array([ analize_sentiment(tweet) for tweet in df_atm['E'] ])
df_sev['Score'] = np.array([ analize_sentiment(tweet) for tweet in df_sev['E'] ])
df_val['Score'] = np.array([ analize_sentiment(tweet) for tweet in df_val['E'] ])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
display(df_rm.head(15))  # We display the DataFrame with updated score
display(df_barca.head(15))
display(df_atm.head(15))
display(df_sev.head(15))
display(df_val.head(15))
# Out:
#                                                   text weekday month day hour  \
# 9    Real #Madrid Prepare World-Record Bid for Kyli...     Wed   May  08   09
# 81   11nt Costa Brava &amp; Mediterranean Jewels Cr...     Wed   May  08   08
# 96   @kingarturo23 how does it feel after donating ...     Wed   May  08   08
# 134  Rumours: #Real Madrid to make massive £240m mo...     Wed   May  08   08
# 182  RT @CzonKim: When i see this corner i remember...     Wed   May  08   08
# 188  RT @I_PraveenMP: Fuck I love this game 👑😎 \n\n...     Wed   May  08   08
# 244  Man City, Arsenal and Chelsea want Adrien Rabi...     Wed   May  08   08
# 245  RT @bigjurgensarmy: So, after beating your mos...     Wed   May  08   08
# 285  RT @NicoSchira: #RealMadrid and Zizou #Zidane ...     Wed   May  08   08
# 287  This is exactly what happen #LFCBarça #FCBarce...     Wed   May  08   08
# 303  Marca #claims Dani Ceballos’s time at Real Mad...     Wed   May  08   08
# ...

# %%
pos_tweets = sum(df_rm['Score']>0)

# %%
print("the number of positive tweets for real madrid: ", pos_tweets)
# Out:
# the number of positive tweets for real madrid:  63

# %%
neu_tweets = sum(df_rm['Score']==0)

# %%
print("the number of neutral tweets for real madrid: ", neu_tweets)
# Out:
# the number of neutral tweets for real madrid:  57

# %%
neg_tweets = sum(df_rm['Score']<0)

# %%
print("the number of negative tweets for real madrid: ", neg_tweets)
# Out:
# the number of negative tweets for real madrid:  12

# %%
pos_tweets_b = sum(df_barca['Score']>0)
neu_tweets_b = sum(df_barca['Score']==0)
neg_tweets_b = sum(df_barca['Score']<0)

# %%
print("the number of positive tweets for barcelona: ", pos_tweets_b)
# Out:
# the number of positive tweets for barcelona:  1219

# %%
print("the number of neutral tweets for barcelona: ", neu_tweets_b)
# Out:
# the number of neutral tweets for barcelona:  1502

# %%
print("the number of negative tweets for barcelona: ", neg_tweets_b)
# Out:
# the number of negative tweets for barcelona:  317

# %%
pos_tweets_atm = sum(df_atm['Score']>0)
neu_tweets_atm = sum(df_atm['Score']==0)
neg_tweets_atm = sum(df_atm['Score']<0)

# %%
print("the number of postive tweets for atletico: ", pos_tweets_atm)
# Out:
# the number of postive tweets for atletico:  22

# %%
print("the number of negative tweets for atletico: ", neg_tweets_atm)
# Out:
# the number of negative tweets for atletico:  0

# %%
print("the number of neutral tweets for atletico: ", neu_tweets_atm)
# Out:
# the number of neutral tweets for atletico:  11

# %%
pos_tweets_sev = sum(df_sev['Score']>0)
neu_tweets_sev = sum(df_sev['Score']==0)
neg_tweets_sev = sum(df_sev['Score']<0)

# %%
print("the number of postive tweets for sevilla: ", pos_tweets_sev)
# Out:
# the number of postive tweets for sevilla:  13

# %%
print("the number of neutral tweets for sevilla: ", neu_tweets_sev)
# Out:
# the number of neutral tweets for sevilla:  13

# %%
print("the number of negative tweets for sevilla: ", neg_tweets_sev)
# Out:
# the number of negative tweets for sevilla:  3

# %%
pos_tweets_val = sum(df_val['Score']>0)
neu_tweets_val = sum(df_val['Score']==0)
neg_tweets_val = sum(df_val['Score']<0)

# %%
print("the number of postive tweets for valencia: ", pos_tweets_val)
# Out:
# the number of postive tweets for valencia:  81

# %%
print("the number of negative tweets for valencia: ", neg_tweets_val)
# Out:
# the number of negative tweets for valencia:  24

# %%
print("the number of neutral tweets for valencia: ", neu_tweets_val)
# Out:
# the number of neutral tweets for valencia:  111

# %%
print('Percentage of Positive tweets for real madrid: ',((pos_tweets)/len(df_rm)*100))
# Out:
# Percentage of Positive tweets for real madrid:  47.72727272727273

# %%
print('Percentage of Neutral tweets for real madrid: ',((neu_tweets)/len(df_rm)*100))
# Out:
# Percentage of Neutral tweets for real madrid:  43.18181818181818

# %%
print('Percentage of Negative tweets for real madrid: ',((neg_tweets)/len(df_rm)*100))
# Out:
# Percentage of Negative tweets for real madrid:  9.090909090909092

# %%
print('Percentage of Positive tweets for barcelona: ',((pos_tweets_b)/len(df_barca)*100))
# Out:
# Percentage of Positive tweets for barcelona:  40.125082290980906

# %%
print('Percentage of Neutral tweets for barcelona: ',((neu_tweets_b)/len(df_barca)*100))
# Out:
# Percentage of Neutral tweets for barcelona:  49.44042132982226

# %%
print('Percentage of Negative tweets for barcelona: ',((neg_tweets_b)/len(df_barca)*100))
# Out:
# Percentage of Negative tweets for barcelona:  10.43449637919684

# %%
print('Percentage of Positive tweets for atletico: ',((pos_tweets_atm)/len(df_atm)*100))
# Out:
# Percentage of Positive tweets for atletico:  66.66666666666666

# %%
print('Percentage of Neutral tweets for atletico: ',((neu_tweets_atm)/len(df_atm)*100))
# Out:
# Percentage of Neutral tweets for atletico:  33.33333333333333

# %%
print('Percentage of Negative tweets for atletico: ',((neg_tweets_atm)/len(df_atm)*100))
# Out:
# Percentage of Negative tweets for atletico:  0.0

# %%
print('Percentage of Positive tweets for Sevilla: ',((pos_tweets_sev)/len(df_sev)*100))
# Out:
# Percentage of Positive tweets for Sevilla:  44.827586206896555

# %%
print('Percentage of Neutral tweets for Sevilla: ',((neu_tweets_sev)/len(df_sev)*100))
# Out:
# Percentage of Neutral tweets for Sevilla:  44.827586206896555

# %%
print('Percentage of Negative tweets for Sevilla: ',((neg_tweets_sev)/len(df_sev)*100))
# Out:
# Percentage of Negative tweets for Sevilla:  10.344827586206897

# %%
print('Percentage of Positive tweets for Valencia: ',((pos_tweets_val)/len(df_val)*100))
# Out:
# Percentage of Positive tweets for Valencia:  37.5

# %%
print('Percentage of Neutral tweets for Valencia: ',((neu_tweets_val)/len(df_val)*100))
# Out:
# Percentage of Neutral tweets for Valencia:  51.388888888888886

# %%
print('Percentage of Negative tweets for Valencia: ',((neg_tweets_val)/len(df_val)*100))
# Out:
# Percentage of Negative tweets for Valencia:  11.11111111111111

# %%
df.head(2)

# %%
from nltk.corpus import stopwords  
from sklearn.feature_extraction.text import CountVectorizer
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Prashant
# [nltk_data]     Chaudhary\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
vectorizer = CountVectorizer(max_features=2500, min_df=7, max_df=0.8, stop_words=stopwords.words('english'))

# %%
df['F'] = df['E']

# %%
df.head()
# Out:
#                                                 text weekday month day hour  \
# 0  Good morning #Barcelona...Good advice for #Bar...     Wed   May  08   09
# 1  RT @YusufChambers: #MoSalah gets injured.\n#ra...     Wed   May  08   09
# 2  👉 @FinalScoresBET #fsb #winfornow this is the ...     Wed   May  08   09
# 3  RT @LFCphoto: No problem. #LFC #LIVBAR #Champi...     Wed   May  08   09
# 4  RT @MARCABIMBO: WE CHOOSE TO BELIEVE IN US @ma...     Wed   May  08   09
#
#    has_hashtag  has_url  fav_count  is_reply  retweet_count  followers  \
# 0            1        1          0         0              0       1691
# 1            1        0          0         0              4         37
# 2            1        1          0         0              0         47
# 3            1        0          0         0             21         38
# 4            1        0          0         0             12        141
#
#    following                  user                    location  screen_name  \
# ...

# %%
df['F'] = vectorizer.fit_transform(df['F']).toarray()

# %%
df.head()
# Out:
#                                                 text weekday month day hour  \
# 0  Good morning #Barcelona...Good advice for #Bar...     Wed   May  08   09
# 1  RT @YusufChambers: #MoSalah gets injured.\n#ra...     Wed   May  08   09
# 2  👉 @FinalScoresBET #fsb #winfornow this is the ...     Wed   May  08   09
# 3  RT @LFCphoto: No problem. #LFC #LIVBAR #Champi...     Wed   May  08   09
# 4  RT @MARCABIMBO: WE CHOOSE TO BELIEVE IN US @ma...     Wed   May  08   09
#
#    has_hashtag  has_url  fav_count  is_reply  retweet_count  followers  \
# 0            1        1          0         0              0       1691
# 1            1        0          0         0              4         37
# 2            1        1          0         0              0         47
# 3            1        0          0         0             21         38
# 4            1        0          0         0             12        141
#
#    following                  user                    location  screen_name  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df['F'], df['Sentiment'], test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

text_classifier = RandomForestClassifier(n_estimators=200, random_state=0)  
text_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
df.head(2)
# Out:
#                                                 text weekday month day hour  \
# 0  Good morning #Barcelona...Good advice for #Bar...     Wed   May  08   09
# 1  RT @YusufChambers: #MoSalah gets injured.\n#ra...     Wed   May  08   09
#
#    has_hashtag  has_url  fav_count  is_reply  retweet_count  followers  \
# 0            1        1          0         0              0       1691
# 1            1        0          0         0              4         37
#
#    following              user                    location screen_name  \
# 0       3473  Pedro de la Vega                   Barcelona      BcnFox
# 1        233            Yaseen  Johannesburg, South Africa  yaseenyazo
#
#                                           lower case  \
# 0  good morning #barcelona...good advice for #bar...
# 1  rt @yusufchambers: #mosalah gets injured.\n#ra...
#
#                                                    E  F  Score Sentiment
# ...

# %%
df['Score'] = np.array([ analize_sentiment(tweet) for tweet in df['E'] ])

# %%
df['Sentiment'] = ["Positive" if x ==1 else "Neutral" if x ==0 else "Negative" for x in df['Score']]

# %%
features = df.iloc[:, 16].values  
labels = df.iloc[:, 19].values

# %%
from nltk.corpus import stopwords  
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features=2500, min_df=7, max_df=0.8, stop_words=stopwords.words('english'))  
features = vectorizer.fit_transform(features).toarray()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

text_classifier = RandomForestClassifier(n_estimators=200, random_state=0)  
text_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
predictions = text_classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score 

print(confusion_matrix(y_test,predictions))  
print(classification_report(y_test,predictions))  
print('Accuracy of the model: ',accuracy_score(y_test, predictions))
# Out:
# [[ 79   5   6]
#  [  2 379   4]
#  [  1  20 316]]
#               precision    recall  f1-score   support
#
#     Negative       0.96      0.88      0.92        90
#      Neutral       0.94      0.98      0.96       385
#     Positive       0.97      0.94      0.95       337
#
#    micro avg       0.95      0.95      0.95       812
#    macro avg       0.96      0.93      0.94       812
# weighted avg       0.95      0.95      0.95       812
#
# Accuracy of the model:  0.9532019704433498

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df['G'] = df['E']

# %%
df.head()
# Out:
#                                                 text weekday month day hour  \
# 0  Good morning #Barcelona...Good advice for #Bar...     Wed   May  08   09
# 1  RT @YusufChambers: #MoSalah gets injured.\n#ra...     Wed   May  08   09
# 2  👉 @FinalScoresBET #fsb #winfornow this is the ...     Wed   May  08   09
# 3  RT @LFCphoto: No problem. #LFC #LIVBAR #Champi...     Wed   May  08   09
# 4  RT @MARCABIMBO: WE CHOOSE TO BELIEVE IN US @ma...     Wed   May  08   09
#
#    has_hashtag  has_url  fav_count  is_reply  retweet_count  ...  following  \
# 0            1        1          0         0              0  ...       3473
# 1            1        0          0         0              4  ...        233
# 2            1        1          0         0              0  ...         30
# 3            1        0          0         0             21  ...        317
# 4            1        0          0         0             12  ...        874
#
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(binary=True)
cv.fit(df['G'])
X = cv.transform(df['G'])

# %%
X_test = cv.transform(df['G'])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
labels = df.iloc[:, 19].values

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, labels, train_size = 0.80
)

for c in [0.01, 0.05, 0.25, 0.5]:
    
    lr = LogisticRegression(C=c)
    lr.fit(X_train, y_train)
    print ("Accuracy for C=%s: %s" 
           % (c, accuracy_score(y_val, lr.predict(X_val))))
# Out:
# Accuracy for C=0.01: 0.7512315270935961
# Accuracy for C=0.05: 0.8448275862068966
# Accuracy for C=0.25: 0.9285714285714286
# Accuracy for C=0.5: 0.9482758620689655

# %%
final_model = LogisticRegression(C=0.5)
final_model.fit(X, labels)
print ("Final Accuracy: %s" 
       % accuracy_score(labels, final_model.predict(X_test)))
# Out:
# Final Accuracy: 0.9955654101995566
